# %% [markdown]
# # Reading data in pandas

# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')
print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
import pandas as pd
df = pd.read_csv('pokemon_data.txt', delimiter='\t')
print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
##Read Headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
## Read Each Column
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
## Read Each Column
print(df[['Name','Type 1' ,'Attack']])
# Out:
#                       Name   Type 1  Attack
# 0                Bulbasaur    Grass      49
# 1                  Ivysaur    Grass      62
# 2                 Venusaur    Grass      82
# 3    VenusaurMega Venusaur    Grass     100
# 4               Charmander     Fire      52
# ..                     ...      ...     ...
# 795                Diancie     Rock     100
# 796    DiancieMega Diancie     Rock     160
# 797    HoopaHoopa Confined  Psychic     110
# 798     HoopaHoopa Unbound  Psychic     160
# 799              Volcanion     Fire     110
#
# [800 rows x 3 columns]

# %%
## Read Each Row
print(df.head(2))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
## Read Each Row
print(df.iloc[2:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 2      100     80           1      False
# 3      120     80           1      False

# %%
## Read Each Row
for index,row in df.iterrows():
    print(index,row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
## Read Specific Location
df.loc[df['HP'] == 39]
# Out:
#        #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander   Fire    NaN  39      52       43       60       50
# 169  155   Cyndaquil   Fire    NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary
# 4       65           1      False
# 169     65           2      False

# %%
## Sorting
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2  Defense  Sp. Def  Sp. Def  \
# 794  718         Zygarde50% Forme   Dragon  Ground      121       95       95
# 695  634                 Zweilous     Dark  Dragon       70       70       70
# 46    41                    Zubat   Poison  Flying       35       40       40
# 631  570                    Zorua     Dark     NaN       40       40       40
# 632  571                  Zoroark     Dark     NaN       60       60       60
# ..   ...                      ...      ...     ...      ...      ...      ...
# 393  359          AbsolMega Absol     Dark     NaN       60       60       60
# 392  359                    Absol     Dark     NaN       60       60       60
# 68    63                     Abra  Psychic     NaN       15       55       55
# 511  460  AbomasnowMega Abomasnow    Grass     Ice      105      105      105
# 510  460                Abomasnow    Grass     Ice       75       85       85
#
# ...

# %%
## making changes data
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] +df['Sp. Def'] + df['Speed']

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
## remove Columns
df = df.drop(columns = ['Total'])
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80  80     100      123      122
# 4  4             Charmander   Fire     NaN  39  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns)
df = df[cols[0:5] + [cols[-1]]+cols[5:12]]
df.head(5)
# Out:
#         #                   Name  Type 1  Type 2      HP  \
# 0       1              Bulbasaur   Grass  Poison      45
# 1       2                Ivysaur   Grass  Poison      60
# 2       3               Venusaur   Grass  Poison      80
# 3       3  VenusaurMega Venusaur   Grass  Poison      80
# 4  Flamer                 Flamer  Flamer  Flamer  Flamer
#
#                                   Total  Attack Defense Sp. Atk Sp. Def  \
# 0                                   318      49      49      65      65
# 1                                   405      62      63      80      80
# 2                                   525      82      83     100     100
# 3                                   625     100     123     122     120
# 4  FlamerFlamerFlamerFlamerFlamerFlamer  Flamer  Flamer  Flamer  Flamer
#
#     Speed Generation Legendary
# 0      45          1     False
# 1      60          1     False
# 2      80          1     False
# 3      80          1     False
# ...

# %%
## to save file as new one
df.to_csv('new.csv')

# %%
## Filtering Data
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[df['Type 1'] == 'Fire' , 'Type 1'] = 'Flamer'
df.head(10)
# Out:
#    #                       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur   Grass  Poison  45      49       49       65
# 1  2                    Ivysaur   Grass  Poison  60      62       63       80
# 2  3                   Venusaur   Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 4  4                 Charmander  Flamer     NaN  39      52       43       60
# 5  5                 Charmeleon  Flamer     NaN  58      64       58       80
# 6  6                  Charizard  Flamer  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X  Flamer  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y  Flamer  Flying  78     104       78      159
# 9  7                   Squirtle   Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  count
# 0       65     45           1      False      1
# ...

# %%
df['count'] = 1
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
for df in pd.read_csv('new.csv',chunksize=10):
    print(df)
# Out:
#    #                       Name Type 1  Type 2  HP  Total  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison  45    318      49       49
# 1  2                    Ivysaur  Grass  Poison  60    405      62       63
# 2  3                   Venusaur  Grass  Poison  80    525      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison  80    625     100      123
# 4  4                 Charmander   Fire     NaN  39    309      52       43
# 5  5                 Charmeleon   Fire     NaN  58    405      64       58
# 6  6                  Charizard   Fire  Flying  78    534      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon  78    634     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying  78    634     104       78
# 9  7                   Squirtle  Water     NaN  44    314      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
new_df = pd.DataFrame(columns = df.columns)
for df in pd.read_csv('new.csv',chunksize=10):
    result = df.groupby(['Type 1']).count()['count']
    new_df = pd.concat([new_df,result])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-2eb797051981> in <module>
# ...
